# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import os

# %% [markdown]
# # Read stock data as dictionary(key : value = stock_code : dataframe)

# %%
# destination directory
dstdir = "../data3"
stocks_dict = {}

# r=root, d=directories, f=files
for r, d, f in os.walk(dstdir):
    for file in f:
        if file.endswith(".csv"):
            stocks_dict[file.split('.')[0]] = pd.read_csv(os.path.join(r, file), 
                                                              names=["date", "open", "high", "low", "close", "s_close5", "s_close10", "s_close20", "s_close60", "s_close120", "total_pattern", "amount", "s_amount5", "s_amount20", "s_amount60", "s_amount120"],
                                                           thousands=',')

# %% [markdown]
# # check the number of stock codes and the first name

# %%
stock_names = list(stocks_dict.keys())
stock_names[0], len(stock_names)
# Out:
# ('000210', 191)

# %% [markdown]
# # Check the tail of the first stock

# %%
first_stock = stocks_dict[stock_names[0]]
first_stock.tail()
# Out:
#            date   open   high    low  close   s_close5  s_close10  s_close20  \
# 595  2020-11-24  83600  85300  82900  84300  83,060.00  82,680.00  81,510.00
# 596  2020-11-25  85000  86600  83500  84500  83,400.00  82,750.00  81,410.00
# 597  2020-11-26  84600  84900  82400  83800  83,780.00  82,990.00  81,430.00
# 598  2020-11-27  84000  85700  83000  84200  84,040.00  83,300.00  81,740.00
# 599  2020-11-30  84300  84300  80000  80000  83,360.00  82,990.00  81,870.00
#
#      s_close60 s_close120  total_pattern   amount   s_amount5  s_amount20  \
# 595  82,841.67  84,240.83              0   379016  261,614.60  357,051.30
# 596  82,940.00  84,145.00              0   496274  323,870.20  340,306.50
# 597  82,850.00  84,065.83              0   298165  334,414.00  332,217.95
# 598  82,805.00  83,976.67              0   319359  344,537.00  309,497.55
# 599  82,568.33  83,874.17             39  1051932  508,949.20  346,340.45
#
#      s_amount60 s_amount120
# 595  397,103.03  316,385.70
# 596  401,642.85  316,853.92
# 597  391,445.48  316,467.92
# 598  383,703.15  317,467.06
# 599  388,056.00  324,042.03

# %% [markdown]
# # 2019-01-08 is the day when first confirmed case of covide 19 was seen in Korea
# # find the indeces of the period before and during corona

# %%
first_stock.index[first_stock['date']=='2019-01-08'].tolist()
# Out:
# [131]

# %%
first_stock.index[first_stock['date']=='2019-11-29'].tolist()
# Out:
# [352]

# %%
first_stock.index[first_stock['date']=='2020-01-08'].tolist()
# Out:
# [377]

# %%
first_stock.index[first_stock['date']=='2020-11-27'].tolist()
# Out:
# [598]

# %% [markdown]
# # Concatenate the stocks with the columns of close price

# %%
print("총", len(stocks_dict), "종목")
if stocks_dict[stock_names[0]].index.is_unique:
    df_stock = stocks_dict[stock_names[0]]
    for i in range(0, len(stocks_dict)-1):
        df_next_stock = stocks_dict[stock_names[i+1]]
        if df_next_stock.index.is_unique:
            df_stock = pd.concat([df_stock[['close']],df_next_stock[['close']]], axis=1)
else:
    print("check if indices are unique")
print("전처리 후", len(df_stock.columns), "종목")
# Out:
# 총 191 종목
# 전처리 후 191 종목

# %% [markdown]
# # Change the names of the columns to stock codes

# %%
df_stock.columns = stock_names

# %%
df_stock.head()
# Out:
#    000210  000215  000720  000725  001880  002995  003070  003075  005965  \
# 0   80700   33350   54000  195500   12300   24400    8890   16500   15050
# 1   76000   31800   55600  173500   12450   22900    8600   15600   15300
# 2   76100   30800   55300  163000   12450   22900    8580   15700   14900
# 3   76500   31600   53100  198500   12750   23900    8300   15900   15200
# 4   73700   30150   55600  179000   13350   22650    8450   15150   16000
#
#    006360  ...  000880  000885  001390  001550  002380  002790  002795  \
# 0   43700  ...   30700   25600   26900   21700  290585  120223   52446
# 1   45200  ...   30800   25050   26850   22300  288829  120722   52645
# 2   45950  ...   30600   25500   26450   23550  287951  125211   51652
# 3   45200  ...   30350   26700   25850   22850  287951  123216   51056
# 4   47550  ...   31350   25000   26700   22800  280050  119724   52248
#
#     00279K  002840  002960
# 0  54100.0   36260  357000
# 1  54000.0   36480  356000
# 2  54600.0   36039  357000
# 3  54900.0   36039  353500
# 4  54500.0   36260  349000
#
# [5 rows x 191 columns]

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Columns: 191 entries, 000210 to 002960
# dtypes: float64(2), int64(189)
# memory usage: 895.4 KB

# %%
len(df_stock.columns)
# Out:
# 191

# %% [markdown]
# # Check if there's a missing value in the dataframe

# %%
s = df_stock.isnull().sum(axis=0)
s
# Out:
# 000210      0
# 000215      0
# 000720      0
# 000725      0
# 001880      0
#          ...
# 002790      0
# 002795      0
# 00279K    366
# 002840      0
# 002960      0
# Length: 191, dtype: int64

# %% [markdown]
# # Find the number of nun-0 values(which mean there's a missing value in the column)

# %%
s.where(s>0).count()
# Out:
# 2

# %% [markdown]
# # Check the stock data

# %%
s2 = s.where(s>0).dropna()

# %%
s2
# Out:
# 00104K    273.0
# 00279K    366.0
# dtype: float64

# %% [markdown]
# # Delete the stock data above

# %%
df_stock = df_stock.dropna(axis=1)

# %%
len(df_stock.columns)
# Out:
# 189

# %%
df_stock.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Split the data into the period of Before-Corona and After-Corona

# %%
df_stock1 = df_stock.iloc[131:353]
df_stock1
# Out:
#      000210  000215  000720  000725  001880  002995  003070  003075  005965  \
# 131   97200   36250   60900  164000   14500   24400    8000   15750   16400
# 132  100000   37250   60900  164000   14600   24850    8010   16000   16850
# 133   96800   37000   61400  163500   14600   25850    8230   15800   17200
# 134   97900   37200   60700  173000   14650   24950    8070   15700   16850
# 135   95900   37250   60800  180000   15050   25600    8180   15900   16850
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 348   94100   40450   40950  146500   20200   40900    9310   16650   18800
# 349   94200   40350   40800  148000   20700   42150    9320   17150   18300
# 350   93600   40200   41350  147000   20450   40750    9340   17100   18450
# 351   92100   40250   40700  144500   20050   40050    9130   16900   18550
# 352   89900   39900   40250  145000   19800   39100    9090   16550   19600
#
#      006360  ...  032640  000880  000885  001390  001550  002380  002790  \
# 131   43450  ...   17900   31600   19050   17950   31650  266443   65250
# 132   43850  ...   17600   32300   19150   18400   31500  258542   66347
# 133   45500  ...   17150   32550   19150   18250   31350  258981   65848
# 134   44700  ...   16750   33550   19150   18200   31450  260736   66347
# 135   45450  ...   16800   33600   19350   18350   31750  255908   68742
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 348   30000  ...   14100   24550   29250   11450   16200  193138   79700
# 349   29700  ...   13950   24800   30500   11400   15700  190943   77300
# 350   30100  ...   13750   24550   30950   11050   15800  194016   79600
# 351   30100  ...   13600   23900   30300   10900   15100  191821   82100
# 352   30100  ...   13400   24050   29300   10850   14750  190504   81200
#
#      002795  002840  002960
# 131   28160   37287  334000
# 132   28110   36920  331500
# 133   28110   36994  329000
# 134   27812   36847  326000
# 135   27812   36773  323500
# ..      ...     ...     ...
# 348   32700   56000  338000
# 349   32850   55500  337000
# 350   32350   56100  334000
# 351   32200   56200  331000
# 352   30650   56100  330500
#
# [222 rows x 189 columns]

# %%
df_stock2 = df_stock.iloc[377:599]
df_stock2
# Out:
#      000210  000215  000720  000725  001880  002995  003070  003075  005965  \
# 377   82600   39300   40600  110500   19250   32200    9520   17150   21450
# 378   83600   39350   41700  122500   19300   33500    9280   17350   21000
# 379   83600   39350   41250  118500   19450   34300    9240   17300   20700
# 380   84100   40150   42050  122500   19450   34300    9320   17350   21000
# 381   84600   40300   41800  120000   19550   34500    9160   17250   20800
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 594   83400   45650   35100  181500   28050   41150   19750   35300   25550
# 595   84300   46900   33600  190000   27800   44000   20500   33800   25050
# 596   84500   48000   34550  183000   28200   41600   20750   33350   25350
# 597   83800   47600   34650  179000   29200   40150   20450   43350   25100
# 598   84200   48500   34950  182500   29600   44150   20450   37300   25000
#
#      006360  ...  032640  000880  000885  001390  001550  002380  002790  \
# 377   29250  ...   13450   23550   34700   11450   15500  204990   84200
# 378   30050  ...   13300   23800   27850   11450   15900  204990   84200
# 379   29950  ...   13100   23700   27550   11400   15950  204990   86400
# 380   30100  ...   13200   23600   27400   12800   15950  204990   90000
# 381   30650  ...   13150   23600   27650   12700   16350  204990   90300
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 594   32900  ...   11450   26350   48000   20000   20350  171000   55200
# 595   31700  ...   11550   25800   48800   20050   19350  171500   55300
# 596   31800  ...   11400   26100   49200   20850   19450  168500   53600
# 597   31800  ...   11950   26700   48500   21400   19450  168500   53700
# 598   32200  ...   12150   26600   48250   21350   19000  170000   52300
#
#      002795  002840  002960
# 377   34950   57400  316000
# 378   35250   58000  317000
# 379   35350   58200  312000
# 380   35150   57800  310000
# 381   33400   57800  309000
# ..      ...     ...     ...
# 594   19600  105500  261500
# 595   19650  104500  268500
# 596   19900  104000  271000
# 597   20150  105000  268000
# 598   20400  105000  265500
#
# [222 rows x 189 columns]

# %% [markdown]
# # Define a function which makes a correlation matrix of stock data and convert the matrix into a graph

# %%
def make_cor_matrix_to_graph(df):
    cor_matrix = df.iloc[:, 0:].corr()
    stock_codes = cor_matrix.index.values
    cor_matrix = np.asmatrix(cor_matrix)
    G = nx.from_numpy_matrix(cor_matrix)
    G = nx.relabel_nodes(G, lambda x: stock_codes[x])
    return G

# %%
# Graph of Before-Corona
G1 = make_cor_matrix_to_graph(df_stock1)
G1.edges(data=True);

# %%
# Graph of After-Corona
G2 = make_cor_matrix_to_graph(df_stock2)
G2.edges(data=True);

# %%
def create_corr_network_5(G, corr_direction, min_correlation):
    period = ""
    
    # For Saving(if G1: Before-Corona, elif G2: After-Corona)
    if G == G1:
        period = "BC"
    else:
        period = "AC"
    
    # Start from Clique
    H = G.copy()
    for stock1, stock2, weight in G.edges(data=True):
        # Delete self loop and unnecessary edges
        if corr_direction == "positive":
            if weight["weight"] == 1:
                H.remove_edge(stock1, stock2)
            if weight["weight"] < 0 or weight["weight"] < min_correlation:
                H.remove_edge(stock1, stock2)
        else:
            if weight["weight"] >= 0 or weight["weight"] > min_correlation:
                H.remove_edge(stock1, stock2)
                
    edges, weights = zip(*nx.get_edge_attributes(H, 'weight').items())
    
    weights = tuple([(1+abs(x))**2 for x in weights])
    
    # Delete nodes which don't have any edges
    d = dict(nx.degree(H))
    for k, v in d.items():
        if v == 0:
            H.remove_node(k)
    d = dict([(k, v) for k, v in d.items() if v>0])
    
    nodelist, node_sizes = zip(*d.items())
    
    # Visualization Part
    positions = nx.spring_layout(H)
    
    plt.figure(figsize=(15,15))
    
    # node size depending on the magnitude of degrees
    nx.draw_networkx_nodes(H,positions,node_color="#DA70D6",nodelist=nodelist,
                          node_size=tuple([x**1.5 for x in node_sizes]),alpha=0.8)
    
    # label with the corresponding stock codes
    labels = {}
    for node in nodelist:
        labels[node] = node
    nx.draw_networkx_labels(H, positions, labels, font_size=12,
                           font_family='sans-serif')
    
    # Edge colour depending on sign of the weights
    if corr_direction == "positive":
        edge_colour = plt.cm.GnBu
    else:
        edge_colour = plt.cm.PuRd
    
    # Check the eigenvector centriality of H
#     centrality = nx.eigenvector_centrality(H)
#     print(['code: %s, cent: %0.2f'%(node,centrality[node]) for node in centrality])
#     print(len(H.nodes()))
    
    # Draw the edges
    nx.draw_networkx_edges(H, positions, edge_list=edges,style='solid',
                          width=weights,edge_colour=weights, edge_cmap=edge_colour,
                          edge_vmin=min(weights), edge_vmax=max(weights))
    
    plt.axis('off')
    
#     nx.write_edgelist(H, "test.edgelist", data=["weight"])

    # Use this code to write the network as net format
#     nx.write_pajek(H, "../net/net_{0}_{1}_{2}.net".format(period, corr_direction, min_correlation))

#     plt.savefig("part5" + corr_direction + ".png", format="PNG")
    plt.show()

# %% [markdown]
# # Visualization for Before-Corona

# %%
create_corr_network_5(G1, corr_direction="negative", min_correlation=-0.1)
# Out:
# 189

# %% [markdown]
# # Visualization for After-Corona

# %%
create_corr_network_5(G2, corr_direction="negative", min_correlation=-0.10)
# Out:
# 188
